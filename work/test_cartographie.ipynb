# %%
# Code correspondant a Pappers API (2.0)
import json
from pprint import pprint
import pandas as pd
from urllib.parse import urlencode
from common.old_request import check_api_key_validity
from common.convert import json_to_yaml, load_yaml_to_dict
from common.path import PAPPERS_API_URL, check_extension, create_parent_directory
from common.keys import PAPPERS_API_KEY_L_LVOLAT_FREE
import re
import math
import requests as rq
from concurrent.futures import ThreadPoolExecutor, as_completed
from dataclasses import asdict, dataclass, field
from typing import Dict, List, Optional, Any


import requests


def make_request_with_api_key(url, output_file, api_key=PAPPERS_API_KEY_L_LVOLAT_FREE):

    # check if the file already exists, then we do not recreate it
    if output_file.exists():
        print(f"result already available in {output_file}")
        return

    headers = {"api-key": api_key}
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        print("Request successful!")
        print("Response:", response.json())
        pprint(response.text)
        # Export the data to a JSON file
        with open(output_file, "w", encoding="utf-8") as file:
            json.dump(response.json(), file, indent=4)
        yaml_path = output_file.with_suffix(".yaml")
        json_to_yaml(output_file, yaml_path)

        print(f"Data has been written to {output_file}")
    else:
        print(f"Request failed with status code {response.status_code}")
        pprint(response.text)
    return response


# Exemple d'utilisation
from common.path import WORK_PATH

siren = "310130323"
params = {"siren": siren}
json_cartopath = WORK_PATH / "pappers_output" / f"output_cartographie_{siren}.json"
json_outputpath = WORK_PATH / "pappers_output" / f"output_siren_{siren}.json"
# Out:
# the API key is correct

# %%
params={"siren":siren,"degre":4}
url = f"{PAPPERS_API_URL}/entreprise/cartographie?&{urlencode(params)}"
print(url)
response = make_request_with_api_key(url, json_cartopath)
dicarto = load_yaml_to_dict(json_cartopath.with_suffix(".yaml"))
# Out:
# https://api.pappers.fr/v2/entreprise/cartographie?&siren=310130323&degre=4
# Request successful!
# Response: {'entreprises': [{'id': 'e1', 'siren': '310130323', 'nom_entreprise': 'GALLA'}, {'id': 'e2', 'siren': '818350167', 'nom_entreprise': 'OFT-MIALANE'}, {'id': 'e3', 'siren': '491591509', 'nom_entreprise': 'MARTHE'}], 'personnes': [{'id': 'p1', 'prenom': 'Fabienne', 'nom': 'Harun', 'niveau': 1, 'date_naissance': '10/1968'}, {'id': 'p2', 'prenom': 'Olivier', 'nom': 'Mialane', 'niveau': 2, 'date_naissance': '11/1967'}], 'liens_entreprises_personnes': [['e1', 'p1'], ['e3', 'p1'], ['e3', 'p2'], ['e2', 'p2']], 'liens_entreprises_entreprises': [['e1', 'e2']]}
# '{"entreprises":[{"id":"e1","siren":"310130323","nom_entreprise":"GALLA"},{"id":"e2","siren":"818350167","nom_entreprise":"OFT-MIALANE"},{"id":"e3","siren":"491591509","nom_entreprise":"MARTHE"}],"personnes":[{"id":"p1","prenom":"Fabienne","nom":"Harun","niveau":1,"date_naissance":"10/1968"},{"id":"p2","prenom":"Olivier","nom":"Mialane","niveau":2,"date_naissance":"11/1967"}],"liens_entreprises_personnes":[["e1","p1"],["e3","p1"],["e3","p2"],["e2","p2"]],"liens_entreprises_entreprises":[["e1","e2"]]}'
# C:\Users\lvolat\Documents\cocoAI\work\pappers_output\output_cartographie_310130323.json converted to C:\Users\lvolat\Documents\cocoAI\work\pappers_output\output_cartographie_310130323.yaml
# Data has been written to C:\Users\lvolat\Documents\cocoAI\work\pappers_output\output_cartographie_310130323.json
# C:\Users\lvolat\Documents\cocoAI\work\pappers_output\output_cartographie_310130323.yaml loaded

# %%
dfentreprises = pd.DataFrame(dicarto['entreprises'])
dfpersonnes = pd.DataFrame(dicarto['personnes'])

# %%
dfentreprises
# Out:
#    id nom_entreprise      siren
# 0  e1          GALLA  310130323
# 1  e2    OFT-MIALANE  818350167
# 2  e3         MARTHE  491591509

# %%
dfpersonnes
# Out:
#   date_naissance  id  niveau      nom    prenom
# 0        10/1968  p1       1    Harun  Fabienne
# 1        11/1967  p2       2  Mialane   Olivier

# %%
yaml_path = json_outputpath.with_suffix(".yaml")
dioutput = load_yaml_to_dict(yaml_path)
# Out:
# C:\Users\lvolat\Documents\cocoAI\work\pappers_output\output_siren_310130323.yaml loaded

# %%
dioutput
# Out:
# {'annee_effectif': 2022,
#  'annee_tranche_effectif': 2022,
#  'association': None,
#  'associe_unique': False,
#  'beneficiaires_effectifs': [{'adresse_ligne_1': '9 avenue de la Maréchale',
#    'adresse_ligne_2': None,
#    'adresse_ligne_3': None,
#    'beneficiaire_representant_legal': False,
#    'code_nationalite': 'FR',
#    'code_pays': 'FR',
#    'code_pays_de_naissance': 'FR',
#    'code_postal': '94420',
#    'code_postal_de_naissance': None,
#    'codes_nationalites': ['FR'],
#    'date_de_naissance_complete_formatee': '25/10/1968',
#    'date_de_naissance_formatee': '10/1968',
#    'date_greffe': '2024-11-29',
#    'details_parts_directes': None,
#    'details_parts_indirectes': None,
#    'details_parts_vocation_titulaire': None,
#    'details_societe_de_gestion': None,
#    'details_votes_directs': None,
#    'details_votes_indirects': None,
#    'detention_autres_moyens_controle': False,
#    'detention_pouvoir_decision_ag': False,
#    'detention_pouvoir_nom_membre_conseil_administration': False,
#    'nationalite': 'Française',
#    'nom': 'Harun',
#    'nom_usage': 'Mialane',
#    'pays': 'FRANCE',
#    'pays_de_naissance': 'FRANCE',
#    'pourcentage_parts': 50,
#    'pourcentage_parts_directes': 0,
#    'pourcentage_parts_indirectes': 50,
#    'pourcentage_parts_vocation_titulaire': None,
#    'pourcentage_votes': 50,
#    'pourcentage_votes_directs': 0,
#    'pourcentage_votes_indirect': 50,
#    'prenom': 'Fabienne',
#    'prenom_usuel': 'Fabienne',
#    'pseudonyme': None,
#    'representant_legal_placement_sans_gestion_delegation': False,
#    'sexe': 'F',
#    'type': None,
#    'ville': 'Le Plessis-Trévise',
#    'ville_de_naissance': 'Montfermeil'},
#   {'adresse_ligne_1': None,
#    'adresse_ligne_2': None,
#    'adresse_ligne_3': None,
#    'beneficiaire_representant_legal': False,
#    'code_nationalite': 'FR',
#    'code_pays': None,
#    'code_pays_de_naissance': None,
#    'code_postal': None,
#    'code_postal_de_naissance': None,
#    'codes_nationalites': ['FR'],
#    'date_de_naissance_complete_formatee': None,
#    'date_de_naissance_formatee': '11/1967',
#    'date_greffe': '2024-11-29',
#    'details_parts_directes': None,
#    'details_parts_indirectes': None,
#    'details_parts_vocation_titulaire': None,
#    'details_societe_de_gestion': None,
#    'details_votes_directs': None,
#    'details_votes_indirects': None,
#    'detention_autres_moyens_controle': False,
#    'detention_pouvoir_decision_ag': False,
#    'detention_pouvoir_nom_membre_conseil_administration': False,
#    'nationalite': 'Française',
#    'nom': 'Mialane',
#    'nom_usage': 'Mialane',
#    'pays': None,
#    'pays_de_naissance': None,
#    'pourcentage_parts': 50,
#    'pourcentage_parts_directes': 0,
#    'pourcentage_parts_indirectes': 50,
#    'pourcentage_parts_vocation_titulaire': None,
#    'pourcentage_votes': 50,
#    'pourcentage_votes_directs': 0,
#    'pourcentage_votes_indirect': 50,
#    'prenom': 'Olivier, Marcel, Justin',
#    'prenom_usuel': 'Olivier',
#    'pseudonyme': None,
#    'representant_legal_placement_sans_gestion_delegation': False,
#    'sexe': 'M',
#    'type': None,
#    'ville': None,
#    'ville_de_naissance': None}],
#  'capital': 153000,
#  'capital_actuel_si_variable': None,
#  'capital_formate': '153 000,00 €',
#  'categorie_juridique': '5710',
#  'code_greffe': '7501',
#  'code_naf': '56.10A',
#  'comptes': [{'annee_cloture': 2023,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': True,
#    'date_cloture': '2023-12-31',
#    'date_depot': '2024-11-08',
#    'date_depot_formate': '08/11/2024',
#    'disponible': True,
#    'disponible_xlsx': True,
#    'nom_fichier_pdf': 'GALLA - Comptes sociaux 2023.pdf',
#    'nom_fichier_xlsx': 'GALLA- Comptes sociaux 2023.xlsx',
#    'token': 'Uk5FQzMxMDEzMDMyMzY3NDZlMDJlY2I4NzBlOTllNTAzZTRlNg',
#    'token_xlsx': 'WEMzMTAxMzAzMjMyMDI0MTEwODIwMjMxMjMx',
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2022,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': True,
#    'date_cloture': '2022-12-31',
#    'date_depot': '2023-10-25',
#    'date_depot_formate': '25/10/2023',
#    'disponible': True,
#    'disponible_xlsx': True,
#    'nom_fichier_pdf': 'GALLA - Comptes sociaux 2022.pdf',
#    'nom_fichier_xlsx': 'GALLA- Comptes sociaux 2022.xlsx',
#    'token': 'Uk5FQzMxMDEzMDMyMzY1NzcyNDNiOWZkMDk5NmQ3MjBkZjZjYQ',
#    'token_xlsx': 'WEMzMTAxMzAzMjMyMDIzMTAyNTIwMjIxMjMx',
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2021,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': True,
#    'date_cloture': '2021-12-31',
#    'date_depot': '2022-12-28',
#    'date_depot_formate': '28/12/2022',
#    'disponible': True,
#    'disponible_xlsx': True,
#    'nom_fichier_pdf': 'GALLA - Comptes sociaux 2021.pdf',
#    'nom_fichier_xlsx': 'GALLA- Comptes sociaux 2021.xlsx',
#    'token': 'Uk5FQzMxMDEzMDMyMzYzZTk3MGVkOTk4YWNhZWNmODI1NzYzYQ',
#    'token_xlsx': 'WEMzMTAxMzAzMjMyMDIyMTIyODIwMjExMjMx',
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2020,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2020-12-31',
#    'date_depot': '2022-03-01',
#    'date_depot_formate': '01/03/2022',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2019,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2019-12-31',
#    'date_depot': '2021-04-28',
#    'date_depot_formate': '28/04/2021',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2018,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': True,
#    'date_cloture': '2018-12-31',
#    'date_depot': '2019-10-15',
#    'date_depot_formate': '15/10/2019',
#    'disponible': False,
#    'disponible_xlsx': True,
#    'nom_fichier_xlsx': 'GALLA- Comptes sociaux 2018.xlsx',
#    'token_xlsx': 'WEMzMTAxMzAzMjMyMDE5MTAwOTIwMTgxMjMx',
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2017,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2017-12-31',
#    'date_depot': '2018-08-06',
#    'date_depot_formate': '06/08/2018',
#    'disponible': True,
#    'disponible_xlsx': True,
#    'nom_fichier_pdf': 'GALLA - Comptes sociaux 2017.pdf',
#    'nom_fichier_xlsx': 'GALLA- Comptes sociaux 2017.xlsx',
#    'token': 'QzMxMDEzMDMyMzIwMTgwODA2MjAxNzEyMzFDUw',
#    'token_xlsx': 'WEMzMTAxMzAzMjMyMDE4MDgwNjIwMTcxMjMx',
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2016,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2016-08-31',
#    'date_depot': '2017-03-31',
#    'date_depot_formate': '31/03/2017',
#    'disponible': True,
#    'disponible_xlsx': True,
#    'nom_fichier_pdf': 'GALLA - Comptes sociaux 2016.pdf',
#    'nom_fichier_xlsx': 'GALLA- Comptes sociaux 2016.xlsx',
#    'token': 'Uk5FQzMxMDEzMDMyMzYzZTk3MGVkOTk4YWNhZWNmODI1NzYzNw',
#    'token_xlsx': 'WEMzMTAxMzAzMjMyMDE3MDMzMTIwMTYwODMx',
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2015,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2015-08-31',
#    'date_depot': '2016-02-19',
#    'date_depot_formate': '19/02/2016',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2014,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2014-08-31',
#    'date_depot': '2015-06-29',
#    'date_depot_formate': '29/06/2015',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2013,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2013-08-31',
#    'date_depot': '2014-04-10',
#    'date_depot_formate': '10/04/2014',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2012,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2012-08-31',
#    'date_depot': '2013-03-04',
#    'date_depot_formate': '04/03/2013',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2011,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2011-08-31',
#    'date_depot': '2012-05-11',
#    'date_depot_formate': '11/05/2012',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2010,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2010-08-31',
#    'date_depot': '2011-03-25',
#    'date_depot_formate': '25/03/2011',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2009,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2009-08-31',
#    'date_depot': '2010-03-11',
#    'date_depot_formate': '11/03/2010',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2008,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2008-08-31',
#    'date_depot': '2009-02-26',
#    'date_depot_formate': '26/02/2009',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2007,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2007-08-31',
#    'date_depot': '2008-03-18',
#    'date_depot_formate': '18/03/2008',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2006,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2006-08-31',
#    'date_depot': '2007-07-13',
#    'date_depot_formate': '13/07/2007',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2005,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2005-08-31',
#    'date_depot': '2006-05-03',
#    'date_depot_formate': '03/05/2006',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2004,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2004-08-31',
#    'date_depot': '2005-07-27',
#    'date_depot_formate': '27/07/2005',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2003,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2003-08-31',
#    'date_depot': '2004-05-06',
#    'date_depot_formate': '06/05/2004',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2002,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2002-08-31',
#    'date_depot': '2003-05-05',
#    'date_depot_formate': '05/05/2003',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2001,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2001-08-31',
#    'date_depot': '2002-05-14',
#    'date_depot_formate': '14/05/2002',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 2000,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '2000-08-31',
#    'date_depot': '2001-05-30',
#    'date_depot_formate': '30/05/2001',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1999,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1999-08-31',
#    'date_depot': '2000-06-15',
#    'date_depot_formate': '15/06/2000',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1998,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1998-08-31',
#    'date_depot': '1999-03-11',
#    'date_depot_formate': '11/03/1999',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1997,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1997-08-31',
#    'date_depot': '1998-04-23',
#    'date_depot_formate': '23/04/1998',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1996,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1996-08-31',
#    'date_depot': '1997-08-12',
#    'date_depot_formate': '12/08/1997',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1995,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1995-08-31',
#    'date_depot': '1996-07-10',
#    'date_depot_formate': '10/07/1996',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1994,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1994-08-31',
#    'date_depot': '1995-03-28',
#    'date_depot_formate': '28/03/1995',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1993,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1993-08-31',
#    'date_depot': '1994-03-29',
#    'date_depot_formate': '29/03/1994',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1992,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1992-08-31',
#    'date_depot': '1993-03-02',
#    'date_depot_formate': '02/03/1993',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1991,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1991-08-31',
#    'date_depot': '1992-04-06',
#    'date_depot_formate': '06/04/1992',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1990,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1990-08-31',
#    'date_depot': '1991-10-29',
#    'date_depot_formate': '29/10/1991',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1989,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1989-08-31',
#    'date_depot': '1990-07-12',
#    'date_depot_formate': '12/07/1990',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1988,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1988-08-31',
#    'date_depot': '1989-12-13',
#    'date_depot_formate': '13/12/1989',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1987,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1987-08-31',
#    'date_depot': '1988-04-28',
#    'date_depot_formate': '28/04/1988',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'},
#   {'annee_cloture': 1986,
#    'confdentialite': False,
#    'confidentialite': False,
#    'confidentialite_compte_de_resultat': False,
#    'date_cloture': '1986-08-31',
#    'date_depot': '1987-05-15',
#    'date_depot_formate': '15/05/1987',
#    'disponible': False,
#    'disponible_xlsx': False,
#    'type_comptes': 'CS'}],
#  'conventions_collectives': [{'confirmee': True,
#    'idcc': 1979,
#    'nom': 'Convention collective nationale des hôtels, cafés, restaurants (HCR)',
#    'pourcentage': None},
#   {'confirmee': True, 'idcc': 9999, 'nom': '', 'pourcentage': None}],
#  'date_cessation': None,
#  'date_cessation_formate': None,
#  'date_cloture_exercice': '31 Décembre',
#  'date_cloture_exercice_exceptionnelle': None,
#  'date_creation': '1977-01-01',
#  'date_creation_formate': '01/01/1977',
#  'date_debut_activite': '1977-06-01',
#  'date_debut_premiere_activite': '1977-06-01',
#  'date_immatriculation_rcs': '1977-06-01',
#  'date_immatriculation_rne': '1977-06-01',
#  'date_premiere_immatriculation_rcs': None,
#  'date_radiation_rcs': None,
#  'date_radiation_rne': None,
#  'date_reouverture': None,
#  'denomination': 'GALLA',
#  'depots_actes': [{'actes': [{'date_acte': None,
#      'date_acte_formate': None,
#      'decision': "Reconstitution de l'actif net",
#      'type': 'Extrait de procès-verbal'}],
#    'date_depot': '2024-11-23',
#    'date_depot_formate': '23/11/2024',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 23-11-2024.pdf',
#    'token': 'Uk5FQTMxMDEzMDMyMzY3NGE4YWI2NzdmZGRlMjA0ODA0MTdmOA'},
#   {'actes': [{'date_acte': '2021-12-30',
#      'date_acte_formate': '30/12/2021',
#      'decision': 'Fin de mission de commissaire aux comptes titulaire',
#      'type': 'Extrait de procès-verbal'},
#     {'date_acte': None,
#      'date_acte_formate': None,
#      'decision': 'Fin de mission de commissaire aux comptes suppléant',
#      'type': 'Extrait de procès-verbal'}],
#    'date_depot': '2022-03-04',
#    'date_depot_formate': '04/03/2022',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 04-03-2022.pdf',
#    'token': 'QW91T2NLbXZYYzVCZV9DMDAyMkExMDAxTDA3MDQ5NUQyMDIyMDMwOUgxNjQ1MjJUUElKVEVTMDAzUERCT1I'},
#   {'actes': [{'date_acte': '2021-12-30',
#      'date_acte_formate': '30/12/2021',
#      'decision': 'Fin de mission de commissaire aux comptes suppléant',
#      'type': 'Extrait de procès-verbal'},
#     {'date_acte': None,
#      'date_acte_formate': None,
#      'decision': 'Fin de mission de commissaire aux comptes titulaire',
#      'type': 'Extrait de procès-verbal'}],
#    'date_depot': '2022-03-04',
#    'date_depot_formate': '04/03/2022',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 04-03-2022.pdf',
#    'token': 'QUI2ZzNHN1pyMmkyTl9DMDAyMkExMDAxTDA3MDQ5NkQyMDIyMDMwOUgxNjQ1MjNUUElKVEVTMDAzUERCT1I'},
#   {'actes': [{'date_acte': '2021-07-12',
#      'date_acte_formate': '12/07/2021',
#      'decision': "Prorogation du délai de réunion de l'A.G. chargée d'approuver les comptes",
#      'type': 'Ordonnance'}],
#    'date_depot': '2021-07-13',
#    'date_depot_formate': '13/07/2021',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 13-07-2021.pdf',
#    'token': 'QXlabGVEMUtaT3RPcF9DMDAyMkExMDAxTDE4Mzg2NkQyMDIxMDcxOEgxMDQ3MjhUUElKVEVTMDAzUERCT1I'},
#   {'actes': [{'date_acte': '2018-06-29',
#      'date_acte_formate': '29/06/2018',
#      'decision': "Poursuite d'activité malgré un actif net devenu inférieur à la moitié du capital social",
#      'type': 'Procès-verbal'}],
#    'date_depot': '2018-08-22',
#    'date_depot_formate': '22/08/2018',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 22-08-2018.pdf',
#    'token': 'QTVCd2J1cXU0cGR1N19DMDAyMkExMDAxTDM3ODEwM0QyMDE4MDkwN0gyMjAzNTFUUElKVEVTMDAzUERCT1I'},
#   {'actes': [{'date_acte': '2017-02-28',
#      'date_acte_formate': '28/02/2017',
#      'decision': "Changement relatif à la date de clôture de l'exercice social au 31/12",
#      'type': "Décision(s) de l'associé unique"},
#     {'date_acte': '2017-02-28',
#      'date_acte_formate': '28/02/2017',
#      'decision': 'Modification(s) statutaire(s)',
#      'type': "Décision(s) de l'associé unique"},
#     {'date_acte': '2017-02-28',
#      'date_acte_formate': '28/02/2017',
#      'decision': None,
#      'type': 'Statuts mis à jour'}],
#    'date_depot': '2017-03-24',
#    'date_depot_formate': '24/03/2017',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 24-03-2017.pdf',
#    'token': 'QUpFdUhja3V2dVZDR19DMDAyMkExMDAxTDMyMzA0M0QyMDE3MDQxMUgxNzUzMjlUUElKVEVTMDAzUERCT1I'},
#   {'actes': [{'date_acte': '2017-01-31',
#      'date_acte_formate': '31/01/2017',
#      'decision': 'Changement de directeur général délégué',
#      'type': "Décision(s) de l'associé unique"},
#     {'date_acte': '2017-01-31',
#      'date_acte_formate': '31/01/2017',
#      'decision': 'Augmentation du capital social',
#      'type': "Décision(s) de l'associé unique"},
#     {'date_acte': '2017-01-31',
#      'date_acte_formate': '31/01/2017',
#      'decision': 'Modification(s) statutaire(s)',
#      'type': "Décision(s) de l'associé unique"},
#     {'date_acte': '2017-01-31',
#      'date_acte_formate': '31/01/2017',
#      'decision': 'Changement de président',
#      'type': "Décision(s) de l'associé unique"},
#     {'date_acte': '2017-01-31',
#      'date_acte_formate': '31/01/2017',
#      'decision': None,
#      'type': 'Statuts mis à jour'}],
#    'date_depot': '2017-03-15',
#    'date_depot_formate': '15/03/2017',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 15-03-2017.pdf',
#    'token': 'QU90djk0Q3AxRmVaY19DMDAyMkExMDAxTDIxOTEwOEQyMDE3MDMzMUgxNjQ3MDVUUElKVEVTMDAzUERCT1I'},
#   {'actes': [{'date_acte': '2016-04-04',
#      'date_acte_formate': '04/04/2016',
#      'decision': "Poursuite d'activité malgré un actif net devenu inférieur à la moitié du capital social",
#      'type': "Procès-verbal d'assemblée générale extraordinaire"}],
#    'date_depot': '2016-04-27',
#    'date_depot_formate': '27/04/2016',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 27-04-2016.pdf',
#    'token': 'QUMzRVpBRU5uRVNmUV9DMDAyMkExMDAxTDEzODU0NEQyMDE2MDUxN0gxNzU3MDNUUElKVEVTMDAzUERCT1I'},
#   {'actes': [{'date_acte': '2015-02-24',
#      'date_acte_formate': '24/02/2015',
#      'decision': 'Changement de commissaire aux comptes titulaire et suppléant',
#      'type': "Procès-verbal d'assemblée générale ordinaire"}],
#    'date_depot': '2015-07-08',
#    'date_depot_formate': '08/07/2015',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 08-07-2015.pdf',
#    'token': 'QTY1MzQ2MTk5MDAwMDAwX0MwMDIyQTEwMDFMNzc1MjcyRDIwMTUwNzI3SDE3MzMyNVRQSUpURVMwMDNQREJPUg'},
#   {'actes': [{'date_acte': '2009-04-01',
#      'date_acte_formate': '01/04/2009',
#      'decision': 'Nomination(s) de directeur(s) général(aux) délégué(s)',
#      'type': "Procès-verbal d'assemblée générale extraordinaire"},
#     {'date_acte': '2009-01-04',
#      'date_acte_formate': '04/01/2009',
#      'decision': None,
#      'type': 'Statuts mis à jour'}],
#    'date_depot': '2009-12-21',
#    'date_depot_formate': '21/12/2009',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 21-12-2009.pdf',
#    'token': 'QVkxTzdXcTk3QmxrdF9SQUNUMl8zMTAxMzAzMjNfNzUwMV8xOTc3QjAzODYxXzIwMDlfMTA5MDk5MDI'},
#   {'actes': [{'date_acte': '2009-04-01',
#      'date_acte_formate': '01/04/2009',
#      'decision': 'Nomination(s) de directeur(s) général(aux) délégué(s)',
#      'type': "Procès-verbal d'assemblée générale extraordinaire"},
#     {'date_acte': '2009-01-04',
#      'date_acte_formate': '04/01/2009',
#      'decision': None,
#      'type': 'Statuts mis à jour'}],
#    'date_depot': '2009-12-21',
#    'date_depot_formate': '21/12/2009',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 21-12-2009.pdf',
#    'token': 'QVE4NjM3YWhidHVsR19SQUNUMl8zMTAxMzAzMjNfNzUwMV8xOTc3QjAzODYxXzIwMDlfMTA5MDk5MDE'},
#   {'actes': [{'date_acte': '2009-02-20',
#      'date_acte_formate': '20/02/2009',
#      'decision': 'Renouvellement de mandat de commissaire aux comptes titulaire',
#      'type': "Procès-verbal d'assemblée générale ordinaire"},
#     {'date_acte': '2009-02-20',
#      'date_acte_formate': '20/02/2009',
#      'decision': 'Renouvellement de mandat de commissaire aux comptes suppléant',
#      'type': "Procès-verbal d'assemblée générale ordinaire"}],
#    'date_depot': '2009-03-13',
#    'date_depot_formate': '13/03/2009',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 13-03-2009.pdf',
#    'token': 'QVRoRk9PTDFVeE5rMV9SQUNUMDkwMDc4Mzc3MQ'},
#   {'actes': [{'date_acte': '2004-12-20',
#      'date_acte_formate': '20/12/2004',
#      'decision': 'Renouvellement de mandat de commissaire aux comptes titulaire',
#      'type': "Procès-verbal d'assemblée générale extraordinaire"},
#     {'date_acte': '2004-12-20',
#      'date_acte_formate': '20/12/2004',
#      'decision': 'Nomination de président',
#      'type': "Procès-verbal d'assemblée générale extraordinaire"},
#     {'date_acte': '2004-12-20',
#      'date_acte_formate': '20/12/2004',
#      'decision': 'Transfert du siège social 9 RUE GREGOIRE DE TOURS 75006 PARIS',
#      'type': "Procès-verbal d'assemblée générale extraordinaire"},
#     {'date_acte': '2004-12-20',
#      'date_acte_formate': '20/12/2004',
#      'decision': 'Changement de forme juridique SOCIETE ANONYME',
#      'type': "Procès-verbal d'assemblée générale extraordinaire"},
#     {'date_acte': '2004-12-20',
#      'date_acte_formate': '20/12/2004',
#      'decision': 'Renouvellement de mandat de commissaire aux comptes suppléant',
#      'type': "Procès-verbal d'assemblée générale extraordinaire"},
#     {'date_acte': '2004-12-02',
#      'date_acte_formate': '02/12/2004',
#      'decision': 'Divers',
#      'type': 'Rapport du commissaire à la transformation'},
#     {'date_acte': '2004-12-20',
#      'date_acte_formate': '20/12/2004',
#      'decision': 'Divers',
#      'type': 'Statuts mis à jour'}],
#    'date_depot': '2005-03-18',
#    'date_depot_formate': '18/03/2005',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 18-03-2005.pdf',
#    'token': 'QW1qT2pjWDc0Z2hocF9SQUNUMDUwMDEzNjg3OQ'},
#   {'actes': [{'date_acte': '2003-01-21',
#      'date_acte_formate': '21/01/2003',
#      'decision': 'Changement de commissaire aux comptes titulaire et suppléant',
#      'type': "Procès-verbal d'assemblée générale ordinaire"},
#     {'date_acte': '2003-01-21',
#      'date_acte_formate': '21/01/2003',
#      'decision': "Renouvellement(s) de mandat(s) d'administrateur(s)",
#      'type': "Procès-verbal d'assemblée générale ordinaire"}],
#    'date_depot': '2003-05-12',
#    'date_depot_formate': '12/05/2003',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 12-05-2003.pdf',
#    'token': 'QW1SeE5CTVVoODduNV9SQUNUMDMwMDEwMjU4MA'},
#   {'actes': [{'date_acte': '2002-10-25',
#      'date_acte_formate': '25/10/2002',
#      'decision': 'Mise en harmonie des statuts NRE DUB 15/5/2001',
#      'type': "Procès-verbal d'assemblée générale extraordinaire"},
#     {'date_acte': '2002-10-25',
#      'date_acte_formate': '25/10/2002',
#      'decision': 'MODALITE EXERCICE DIRECTION GENERALE',
#      'type': "Procès-verbal du conseil d'administration"},
#     {'date_acte': '2002-10-25',
#      'date_acte_formate': '25/10/2002',
#      'decision': 'Divers',
#      'type': 'Statuts mis à jour'}],
#    'date_depot': '2003-01-06',
#    'date_depot_formate': '06/01/2003',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 06-01-2003.pdf',
#    'token': 'QUtDSlE2MG1BMEhvWl9SQUNUMDMwMDIwMjA3Mw'},
#   {'actes': [{'date_acte': '2001-12-21',
#      'date_acte_formate': '21/12/2001',
#      'decision': 'Conversion du capital en euros',
#      'type': "Procès-verbal d'assemblée générale extraordinaire"},
#     {'date_acte': '2001-12-21',
#      'date_acte_formate': '21/12/2001',
#      'decision': 'Augmentation du capital social',
#      'type': "Procès-verbal d'assemblée générale extraordinaire"},
#     {'date_acte': '2001-12-21',
#      'date_acte_formate': '21/12/2001',
#      'decision': 'Divers',
#      'type': 'Statuts mis à jour'}],
#    'date_depot': '2002-08-07',
#    'date_depot_formate': '07/08/2002',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 07-08-2002.pdf',
#    'token': 'QUt2S3J3NWhYVkxvSV9SQUNUMDIwMDAxNzQ2OA'},
#   {'actes': [{'date_acte': '1997-02-14',
#      'date_acte_formate': '14/02/1997',
#      'decision': 'Renouvellement de mandat de commissaire aux comptes suppléant',
#      'type': "Procès-verbal d'assemblée générale ordinaire"},
#     {'date_acte': '1997-02-14',
#      'date_acte_formate': '14/02/1997',
#      'decision': 'Renouvellement de mandat de commissaire aux comptes titulaire',
#      'type': "Procès-verbal d'assemblée générale ordinaire"},
#     {'date_acte': '1997-02-14',
#      'date_acte_formate': '14/02/1997',
#      'decision': "Renouvellement(s) de mandat(s) d'administrateur(s)",
#      'type': "Procès-verbal d'assemblée générale ordinaire"},
#     {'date_acte': '1997-02-14',
#      'date_acte_formate': '14/02/1997',
#      'decision': 'Renouvellement de mandat de président',
#      'type': "Procès-verbal du conseil d'administration"}],
#    'date_depot': '1997-08-12',
#    'date_depot_formate': '12/08/1997',
#    'disponible': True,
#    'nom_fichier_pdf': 'GALLA - Actes du 12-08-1997.pdf',
#    'token': 'QW4xNFRYNW1ibmVQTl9SQUNUOTcwMDQzMTU4MA'}],
#  'dernier_traitement': '2024-11-26',
#  'derniere_mise_a_jour_rcs': '2024-12-18',
#  'derniere_mise_a_jour_rne': '2024-12-18',
#  'derniere_mise_a_jour_sirene': '2024-11-27',
#  'derniers_statuts': {'date_acte': '2017-02-28',
#   'date_acte_formate': '28/02/2017',
#   'date_depot': '2017-03-24',
#   'date_depot_formate': '24/03/2017',
#   'decision': None,
#   'disponible': True,
#   'nom_fichier_pdf': 'GALLA - Actes du 24-03-2017.pdf',
#   'token': 'QUpFdUhja3V2dVZDR19DMDAyMkExMDAxTDMyMzA0M0QyMDE3MDQxMUgxNzUzMjlUUElKVEVTMDAzUERCT1I',
#   'type': 'Statuts mis à jour'},
#  'devise_capital': 'Euros',
#  'diffusable': True,
#  'domaine_activite': 'Restauration',
#  'duree_personne_morale': '50',
#  'economie_sociale_solidaire': False,
#  'effectif': 'Entre 20 et 49 salariés',
#  'effectif_max': 49,
#  'effectif_min': 20,
#  'entreprise_cessee': False,
#  'entreprise_employeuse': True,
#  'etablissements': [{'adresse_ligne_1': '33 RUE DU PONT NEUF',
#    'adresse_ligne_2': None,
#    'annee_effectif': 2022,
#    'code_naf': '56.10A',
#    'code_pays': 'FR',
#    'code_postal': '75001',
#    'complement_adresse': None,
#    'date_cessation': None,
#    'date_de_creation': '1980-07-01',
#    'diffusion_partielle': False,
#    'domiciliation': None,
#    'effectif': 'Entre 20 et 49 salariés',
#    'effectif_max': 49,
#    'effectif_min': 20,
#    'enseigne': ' LE CHIEN QUI FUME ',
#    'etablissement_cesse': False,
#    'etablissement_employeur': True,
#    'indice_repetition': None,
#    'latitude': 48.86131199980185,
#    'libelle_code_naf': 'Restauration traditionnelle',
#    'libelle_voie': 'DU PONT NEUF',
#    'longitude': 2.3448640000027132,
#    'nic': '00028',
#    'nom_commercial': None,
#    'numero_voie': 33,
#    'pays': 'France',
#    'predecesseurs': [{'continuite_economique': True,
#      'date': '2005-01-01',
#      'siret': '31013032300010',
#      'transfert_siege': True}],
#    'siege': True,
#    'siret': '31013032300028',
#    'siret_formate': '310 130 323 00028',
#    'tranche_effectif': '12',
#    'type_voie': 'RUE',
#    'ville': 'PARIS'},
#   {'adresse_ligne_1': '9 RUE GREGOIRE DE TOURS',
#    'adresse_ligne_2': None,
#    'annee_effectif': None,
#    'code_naf': '55.3A',
#    'code_pays': 'FR',
#    'code_postal': '75006',
#    'complement_adresse': None,
#    'date_cessation': '2005-01-01',
#    'date_de_creation': '1982-10-22',
#    'diffusion_partielle': False,
#    'domiciliation': None,
#    'effectif': 'Au moins 1 salarié',
#    'effectif_max': 500000,
#    'effectif_min': 1,
#    'enseigne': 'AU BEAUJOLAIS',
#    'etablissement_cesse': True,
#    'etablissement_employeur': True,
#    'indice_repetition': None,
#    'latitude': 48.853278999801844,
#    'libelle_code_naf': 'Restauration de type traditionnel',
#    'libelle_voie': 'GREGOIRE DE TOURS',
#    'longitude': 2.337936000002742,
#    'nic': '00010',
#    'nom_commercial': None,
#    'numero_voie': 9,
#    'pays': 'France',
#    'siege': False,
#    'siret': '31013032300010',
#    'siret_formate': '310 130 323 00010',
#    'successeurs': [{'continuite_economique': False,
#      'date': '2005-05-09',
#      'siret': '48185864500015',
#      'transfert_siege': False},
#     {'continuite_economique': True,
#      'date': '2005-01-01',
#      'siret': '31013032300028',
#      'transfert_siege': True}],
#    'tranche_effectif': None,
#    'type_voie': 'RUE',
#    'ville': 'PARIS'}],
#  'extrait_immatriculation': {'token': 'SzMxMDEzMDMyMw'},
#  'finances': [{'BFR': -371193,
#    'BFR_exploitation': -171479,
#    'BFR_exploitation_jours_CA': None,
#    'BFR_hors_exploitation': -199714,
#    'BFR_hors_exploitation_jours_CA': None,
#    'BFR_jours_CA': None,
#    'annee': 2023,
#    'autonomie_financiere': 22.2,
#    'capacite_autofinancement': None,
#    'capacite_autofinancement_CA': None,
#    'capacite_remboursement': None,
#    'chiffre_affaires': None,
#    'chiffre_affaires_export': None,
#    'couverture_BFR': 0.2,
#    'couverture_dettes': 3,
#    'date_de_cloture_exercice': '2023-12-31',
#    'delai_paiement_clients_jours': None,
#    'delai_paiement_fournisseurs_jours': None,
#    'dettes_financieres': 694559,
#    'duree_exercice': 12,
#    'effectif': None,
#    'etat_dettes_1_an_au_plus': 1018666,
#    'excedent_brut_exploitation': None,
#    'fonds_propres': 371769,
#    'fonds_roulement_net_global': -58824,
#    'impots_taxes': None,
#    'liquidite_generale': 0.5,
#    'marge_brute': None,
#    'marge_nette': None,
#    'ratio_endettement': 1,
#    'ratio_stock_CA_jours': None,
#    'rentabilite_economique': None,
#    'rentabilite_fonds_propres': None,
#    'resultat': 311372,
#    'resultat_exploitation': None,
#    'salaires_CA': None,
#    'salaires_charges_sociales': None,
#    'taux_croissance_chiffre_affaires': None,
#    'taux_levier': None,
#    'taux_marge_EBITDA': None,
#    'taux_marge_brute': None,
#    'taux_marge_operationnelle': None,
#    'tresorerie': 312369,
#    'valeur_ajoutee': None,
#    'valeur_ajoutee_CA': None},
#   {'BFR': -418311,
#    'BFR_exploitation': -161598,
#    'BFR_exploitation_jours_CA': None,
#    'BFR_hors_exploitation': -256713,
#    'BFR_hors_exploitation_jours_CA': None,
#    'BFR_jours_CA': None,
#    'annee': 2022,
#    'autonomie_financiere': 3.4,
#    'capacite_autofinancement': None,
#    'capacite_autofinancement_CA': None,
#    'capacite_remboursement': None,
#    'chiffre_affaires': None,
#    'chiffre_affaires_export': None,
#    'couverture_BFR': 0.2,
#    'couverture_dettes': 1.7,
#    'date_de_cloture_exercice': '2022-12-31',
#    'delai_paiement_clients_jours': None,
#    'delai_paiement_fournisseurs_jours': None,
#    'dettes_financieres': 1102315,
#    'duree_exercice': 12,
#    'effectif': None,
#    'etat_dettes_1_an_au_plus': 1728859,
#    'excedent_brut_exploitation': None,
#    'fonds_propres': 60397,
#    'fonds_roulement_net_global': -84004,
#    'impots_taxes': None,
#    'liquidite_generale': 0.3,
#    'marge_brute': None,
#    'marge_nette': None,
#    'ratio_endettement': 12.7,
#    'ratio_stock_CA_jours': None,
#    'rentabilite_economique': None,
#    'rentabilite_fonds_propres': None,
#    'resultat': 156250,
#    'resultat_exploitation': None,
#    'salaires_CA': None,
#    'salaires_charges_sociales': None,
#    'taux_croissance_chiffre_affaires': None,
#    'taux_levier': None,
#    'taux_marge_EBITDA': None,
#    'taux_marge_brute': None,
#    'taux_marge_operationnelle': None,
#    'tresorerie': 334308,
#    'valeur_ajoutee': None,
#    'valeur_ajoutee_CA': None},
#   {'BFR': -373595,
#    'BFR_exploitation': -119260,
#    'BFR_exploitation_jours_CA': None,
#    'BFR_hors_exploitation': -254335,
#    'BFR_hors_exploitation_jours_CA': None,
#    'BFR_jours_CA': None,
#    'annee': 2021,
#    'autonomie_financiere': -4.8,
#    'capacite_autofinancement': None,
#    'capacite_autofinancement_CA': None,
#    'capacite_remboursement': None,
#    'chiffre_affaires': None,
#    'chiffre_affaires_export': None,
#    'couverture_BFR': -0.4,
#    'couverture_dettes': 1.3,
#    'date_de_cloture_exercice': '2021-12-31',
#    'delai_paiement_clients_jours': None,
#    'delai_paiement_fournisseurs_jours': None,
#    'dettes_financieres': 1520041,
#    'duree_exercice': 12,
#    'effectif': None,
#    'etat_dettes_1_an_au_plus': 1034478,
#    'excedent_brut_exploitation': None,
#    'fonds_propres': -95852,
#    'fonds_roulement_net_global': 138084,
#    'impots_taxes': None,
#    'liquidite_generale': 0.7,
#    'marge_brute': None,
#    'marge_nette': None,
#    'ratio_endettement': -10.5,
#    'ratio_stock_CA_jours': None,
#    'rentabilite_economique': None,
#    'rentabilite_fonds_propres': None,
#    'resultat': 232408,
#    'resultat_exploitation': None,
#    'salaires_CA': None,
#    'salaires_charges_sociales': None,
#    'taux_croissance_chiffre_affaires': None,
#    'taux_levier': None,
#    'taux_marge_EBITDA': None,
#    'taux_marge_brute': None,
#    'taux_marge_operationnelle': None,
#    'tresorerie': 511679,
#    'valeur_ajoutee': None,
#    'valeur_ajoutee_CA': None},
#   {'BFR': -329925,
#    'BFR_exploitation': -138413,
#    'BFR_exploitation_jours_CA': None,
#    'BFR_hors_exploitation': -191512,
#    'BFR_hors_exploitation_jours_CA': None,
#    'BFR_jours_CA': None,
#    'annee': 2018,
#    'autonomie_financiere': -20.4,
#    'capacite_autofinancement': None,
#    'capacite_autofinancement_CA': None,
#    'capacite_remboursement': None,
#    'chiffre_affaires': None,
#    'chiffre_affaires_export': None,
#    'couverture_BFR': 0.5,
#    'couverture_dettes': 1,
#    'date_de_cloture_exercice': '2018-12-31',
#    'delai_paiement_clients_jours': None,
#    'delai_paiement_fournisseurs_jours': None,
#    'dettes_financieres': 1947569,
#    'duree_exercice': 12,
#    'effectif': None,
#    'etat_dettes_1_an_au_plus': 906063,
#    'excedent_brut_exploitation': None,
#    'fonds_propres': -411657,
#    'fonds_roulement_net_global': -158350,
#    'impots_taxes': None,
#    'liquidite_generale': 0.3,
#    'marge_brute': None,
#    'marge_nette': None,
#    'ratio_endettement': -4.3,
#    'ratio_stock_CA_jours': None,
#    'rentabilite_economique': None,
#    'rentabilite_fonds_propres': None,
#    'resultat': -234106,
#    'resultat_exploitation': None,
#    'salaires_CA': None,
#    'salaires_charges_sociales': None,
#    'taux_croissance_chiffre_affaires': None,
#    'taux_levier': None,
#    'taux_marge_EBITDA': None,
#    'taux_marge_brute': None,
#    'taux_marge_operationnelle': None,
#    'tresorerie': 171575,
#    'valeur_ajoutee': None,
#    'valeur_ajoutee_CA': None},
#   {'BFR': -247543,
#    'BFR_exploitation': -150439,
#    'BFR_exploitation_jours_CA': -22.1,
#    'BFR_hors_exploitation': -97104,
#    'BFR_hors_exploitation_jours_CA': -14.3,
#    'BFR_jours_CA': -36.4,
#    'annee': 2017,
#    'autonomie_financiere': -13.3,
#    'capacite_autofinancement': -325466,
#    'capacite_autofinancement_CA': -13.1,
#    'capacite_remboursement': -2.3,
#    'chiffre_affaires': 2481919,
#    'chiffre_affaires_export': 0,
#    'couverture_BFR': -0.2,
#    'couverture_dettes': 1.2,
#    'date_de_cloture_exercice': '2017-12-31',
#    'delai_paiement_clients_jours': 0.3,
#    'delai_paiement_fournisseurs_jours': 50.4,
#    'dettes_financieres': 1036073,
#    'duree_exercice': 12,
#    'effectif': None,
#    'etat_dettes_1_an_au_plus': 824126,
#    'excedent_brut_exploitation': -318322,
#    'fonds_propres': -177551,
#    'fonds_roulement_net_global': 38958,
#    'impots_taxes': 55592,
#    'liquidite_generale': 0.6,
#    'marge_brute': 1936429,
#    'marge_nette': -16.4,
#    'ratio_endettement': -4.2,
#    'ratio_stock_CA_jours': 2.5,
#    'rentabilite_economique': -30.3,
#    'rentabilite_fonds_propres': 228.9,
#    'resultat': -406452,
#    'resultat_exploitation': -347101,
#    'salaires_CA': 60.2,
#    'salaires_charges_sociales': 1493314,
#    'taux_croissance_chiffre_affaires': 31,
#    'taux_levier': -2.4,
#    'taux_marge_EBITDA': -12.8,
#    'taux_marge_brute': 78,
#    'taux_marge_operationnelle': -14,
#    'tresorerie': 286501,
#    'valeur_ajoutee': 1222871,
#    'valeur_ajoutee_CA': 49.3},
#   {'BFR': -373782,
#    'BFR_exploitation': -221450,
#    'BFR_exploitation_jours_CA': -42.7,
#    'BFR_hors_exploitation': -152332,
#    'BFR_hors_exploitation_jours_CA': -29.3,
#    'BFR_jours_CA': -72,
#    'annee': 2016,
#    'autonomie_financiere': -61.1,
#    'capacite_autofinancement': -235851,
#    'capacite_autofinancement_CA': -12.4,
#    'capacite_remboursement': -1.4,
#    'chiffre_affaires': 1894609,
#    'chiffre_affaires_export': 0,
#    'couverture_BFR': 0.8,
#    'couverture_dettes': 1.2,
#    'date_de_cloture_exercice': '2016-08-31',
#    'delai_paiement_clients_jours': 0,
#    'delai_paiement_fournisseurs_jours': 97.8,
#    'dettes_financieres': 403326,
#    'duree_exercice': 12,
#    'effectif': 31,
#    'etat_dettes_1_an_au_plus': 644788,
#    'excedent_brut_exploitation': -227874,
#    'fonds_propres': -346525,
#    'fonds_roulement_net_global': -290227,
#    'impots_taxes': 45740,
#    'liquidite_generale': 0.3,
#    'marge_brute': 1441761,
#    'marge_nette': -13.4,
#    'ratio_endettement': -0.9,
#    'ratio_stock_CA_jours': 4.2,
#    'rentabilite_economique': -44.8,
#    'rentabilite_fonds_propres': 73.3,
#    'resultat': -254027,
#    'resultat_exploitation': -246050,
#    'salaires_CA': 61.9,
#    'salaires_charges_sociales': 1172552,
#    'taux_croissance_chiffre_affaires': -20.8,
#    'taux_levier': -1.4,
#    'taux_marge_EBITDA': -12,
#    'taux_marge_brute': 76.1,
#    'taux_marge_operationnelle': -13,
#    'tresorerie': 83555,
#    'valeur_ajoutee': 978537,
#    'valeur_ajoutee_CA': 51.6},
#   {'BFR': -288639,
#    'BFR_exploitation': -175971,
#    'BFR_exploitation_jours_CA': -26.8,
#    'BFR_hors_exploitation': -112668,
#    'BFR_hors_exploitation_jours_CA': -17.2,
#    'BFR_jours_CA': -44,
#    'annee': 2015,
#    'autonomie_financiere': -15.4,
#    'capacite_autofinancement': -198191,
#    'capacite_autofinancement_CA': -8.3,
#    'capacite_remboursement': -0.8,
#    'chiffre_affaires': 2392479,
#    'chiffre_affaires_export': None,
#    'couverture_BFR': 0.6,
#    'couverture_dettes': 2.4,
#    'date_de_cloture_exercice': '2015-08-31',
#    'delai_paiement_clients_jours': 0,
#    'delai_paiement_fournisseurs_jours': 67.9,
#    'dettes_financieres': 281100,
#    'duree_exercice': 12,
#    'effectif': None,
#    'etat_dettes_1_an_au_plus': None,
#    'excedent_brut_exploitation': -172487,
#    'fonds_propres': -92498,
#    'fonds_roulement_net_global': -169578,
#    'impots_taxes': 64072,
#    'liquidite_generale': None,
#    'marge_brute': 1815421,
#    'marge_nette': -14.5,
#    'ratio_endettement': -1.8,
#    'ratio_stock_CA_jours': 4.6,
#    'rentabilite_economique': -57.8,
#    'rentabilite_fonds_propres': 375.7,
#    'resultat': -347517,
#    'resultat_exploitation': -193838,
#    'salaires_CA': 57.6,
#    'salaires_charges_sociales': 1377837,
#    'taux_croissance_chiffre_affaires': None,
#    'taux_levier': -0.9,
#    'taux_marge_EBITDA': -7.2,
#    'taux_marge_brute': 75.9,
#    'taux_marge_operationnelle': -8.1,
#    'tresorerie': 119061,
#    'valeur_ajoutee': 1274316,
#    'valeur_ajoutee_CA': 53.3}],
#  'finances_consolidees': [],
#  'forme_exercice': 'Commerciale',
#  'forme_juridique': 'SAS, société par actions simplifiée',
#  'formes_exercice': ['Commerciale'],
#  'greffe': 'PARIS',
#  'libelle_code_naf': 'Restauration traditionnelle',
#  'nom': None,
#  'nom_entreprise': 'GALLA',
#  'numero_rcs': '310 130 323 R.C.S. Paris',
#  'numero_tva_intracommunautaire': 'FR58310130323',
#  'objet_social': 'CAFE RESTAURANT',
#  'opposition_utilisation_commerciale': False,
#  'personne_morale': True,
#  'prenom': None,
#  'procedure_collective_en_cours': False,
#  'procedure_collective_existe': False,
#  'procedures_collectives': [],
#  'prochaine_date_cloture_exercice': '2025-12-31',
#  'prochaine_date_cloture_exercice_formate': '31/12/2025',
#  'publications_bodacc': [{'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2024-11-26',
#    'date_cloture': '2023-12-31',
#    'denomination': 'GALLA',
#    'descriptif': "Les comptes annuels sont accompagnés d'une déclaration de confidentialité en application du premier ou deuxième alinéa de l'article L. 232-25.",
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '4980',
#    'numero_parution': '20240228',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2023-11-24',
#    'date_cloture': '2022-12-31',
#    'denomination': 'GALLA',
#    'descriptif': "Les comptes annuels sont accompagnés d'une déclaration de confidentialité en application du premier ou deuxième alinéa de l'article L. 232-25.",
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '3751',
#    'numero_parution': '20230227',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2023-01-13',
#    'date_cloture': '2021-12-31',
#    'denomination': 'GALLA',
#    'descriptif': "Les comptes annuels sont accompagnés d'une déclaration de confidentialité en application du premier ou deuxième alinéa de l'article L. 232-25.",
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '1429',
#    'numero_parution': '20230009',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2022-03-16',
#    'date_cloture': '2020-12-31',
#    'denomination': 'GALLA',
#    'descriptif': "Les comptes annuels sont accompagnés d'une déclaration de confidentialité en application du premier ou deuxième alinéa de l'article L. 232-25.",
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '3417',
#    'numero_parution': '20220053',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'activite': None,
#    'administration': "Commissaire aux comptes titulaire partant : BUREAU D'EXPERTISE ET DE SYNTHESE COMPTABLE - B.E.S.C",
#    'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'capital': 153000,
#    'date': '2022-03-15',
#    'date_debut_activite': None,
#    'denomination': 'GALLA',
#    'description': "modification survenue sur l'administration",
#    'devise_capital': 'EUR',
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'nationnalite': None,
#    'nom': None,
#    'nom_commercial': None,
#    'nom_entreprise': 'GALLA',
#    'numero_annonce': '3008',
#    'numero_parution': '20220052',
#    'personne_morale': True,
#    'prenom': None,
#    'pseudonyme': None,
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Modification'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2021-05-09',
#    'date_cloture': '2019-12-31',
#    'denomination': 'GALLA',
#    'descriptif': "Les comptes annuels sont accompagnés d'une déclaration de confidentialité en application du premier ou deuxième alinéa de l'article L. 232-25.",
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '3291',
#    'numero_parution': '20210091',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2019-10-25',
#    'date_cloture': '2018-12-31',
#    'denomination': 'GALLA',
#    'descriptif': "Les comptes annuels sont accompagnés d'une déclaration de confidentialité en application du premier ou deuxième alinéa de l'article L. 232-25.",
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '1456',
#    'numero_parution': '20190207',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2018-09-04',
#    'date_cloture': '2017-12-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '6134',
#    'numero_parution': '20180162',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2017-04-27',
#    'date_cloture': '2016-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '5551',
#    'numero_parution': '20170035',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'activite': None,
#    'administration': "Président partant : Llana, Jean Francois,  nomination du Président : OFT-MIALANE,  Directeur général délégué partant : Archer, nom d'usage : Archer Llana, Marcia,  nomination du Directeur général délégué : Harun, nom d'usage : Mialane, Fabienne Marthe Pierrette",
#    'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'capital': 153000,
#    'date': '2017-03-26',
#    'date_debut_activite': None,
#    'denomination': 'GALLA',
#    'description': "modification survenue sur l'administration",
#    'devise_capital': 'EUR',
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'nationnalite': None,
#    'nom': None,
#    'nom_commercial': None,
#    'nom_entreprise': 'GALLA',
#    'numero_annonce': '1148',
#    'numero_parution': '20170060',
#    'personne_morale': True,
#    'prenom': None,
#    'pseudonyme': None,
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Modification'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2016-03-18',
#    'date_cloture': '2015-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '3592',
#    'numero_parution': '20160030',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2015-07-28',
#    'date_cloture': '2014-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '7756',
#    'numero_parution': '20150067',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'activite': None,
#    'administration': "Commissaire aux comptes titulaire partant : Berat, Christian, nomination du Commissaire aux comptes titulaire : BUREAU D'EXPERTISE ET DE SYNTHESE COMPTABLE - B.E.S.C., Commissaire aux comptes suppléant partant : AUDIREV (SA), nomination du Commissaire aux comptes suppléant : Berat, nom d'usage : Jouffrey, Valérie",
#    'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'capital': 153000,
#    'date': '2015-07-23',
#    'date_debut_activite': None,
#    'denomination': 'GALLA',
#    'description': "modification survenue sur l'administration",
#    'devise_capital': 'EUR',
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'nationnalite': None,
#    'nom': None,
#    'nom_commercial': None,
#    'nom_entreprise': 'GALLA',
#    'numero_annonce': '998',
#    'numero_parution': '20150139',
#    'personne_morale': True,
#    'prenom': None,
#    'pseudonyme': None,
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Modification'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2014-05-22',
#    'date_cloture': '2013-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '11082',
#    'numero_parution': '20140028',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2013-04-08',
#    'date_cloture': '2012-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '9468',
#    'numero_parution': '20130019',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2012-06-25',
#    'date_cloture': '2011-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '8401',
#    'numero_parution': '20120032',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2011-07-04',
#    'date_cloture': '2010-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '5703',
#    'numero_parution': '20110035',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 R DU PONT NEUF 75001 PARIS',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2010-05-10',
#    'date_cloture': '2009-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '7822',
#    'numero_parution': '20100025',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'activite': None,
#    'administration': "nomination du Directeur général délégué : Archer, nom d'usage : Archer Llana, Marcia",
#    'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'B',
#    'capital': 153000,
#    'date': '2010-01-08',
#    'date_debut_activite': None,
#    'denomination': 'GALLA',
#    'description': "modification survenue sur l'administration",
#    'devise_capital': 'EUR',
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'nationnalite': None,
#    'nom': None,
#    'nom_commercial': None,
#    'nom_entreprise': 'GALLA',
#    'numero_annonce': '1004',
#    'numero_parution': '20100005',
#    'personne_morale': True,
#    'prenom': None,
#    'pseudonyme': None,
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Modification'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2009-04-16',
#    'date_cloture': '2008-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '7311',
#    'numero_parution': '20090025',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2008-05-20',
#    'date_cloture': '2007-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '6032',
#    'numero_parution': '20080026',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'},
#   {'adresse': '33 rue du Pont Neuf 75001 Paris',
#    'annonce_rectificative': False,
#    'bodacc': 'C',
#    'date': '2008-05-20',
#    'date_cloture': '2007-08-31',
#    'denomination': 'GALLA',
#    'descriptif': None,
#    'forme_juridique': 'Société par actions simplifiée',
#    'greffe': 'Paris',
#    'numero_annonce': '6031',
#    'numero_parution': '20080026',
#    'rcs': 'de Paris',
#    'sigle': None,
#    'type': 'Dépôt des comptes',
#    'type_depot': 'Comptes annuels et rapports'}],
#  'representants': [{'adresse_ligne_1': '9 avenue de la Marechale',
#    'adresse_ligne_2': None,
#    'adresse_ligne_3': None,
#    'code_pays': 'FR',
#    'code_postal': '94420',
#    'date_prise_de_poste': '2017-01-31',
#    'denomination': 'OFT-MIALANE',
#    'forme_juridique': 'Société à responsabilité limitée (sans autre indication)',
#    'nom_complet': 'OFT-MIALANE',
#    'pays': 'FRANCE',
#    'personne_morale': True,
#    'qualite': 'Président',
#    'qualites': ['Président'],
#    'siren': '818350167',
#    'ville': 'Le Plessis-Trevise'},
#   {'adresse_ligne_1': '9 avenue de la Maréchale',
#    'adresse_ligne_2': None,
#    'adresse_ligne_3': None,
#    'age': 56,
#    'code_nationalite': 'FR',
#    'code_nationalité': 'FR',
#    'code_pays': 'FR',
#    'code_pays_de_naissance': 'FR',
#    'code_postal': '94420',
#    'codes_nationalites': ['FR'],
#    'date_de_naissance': '1968-10-25',
#    'date_de_naissance_formate': '25/10/1968',
#    'date_de_naissance_rgpd': '1968-10',
#    'date_de_naissance_rgpd_formatee': '10/1968',
#    'date_prise_de_poste': '2017-01-31',
#    'nationalite': 'Française',
#    'nom': 'Harun',
#    'nom_complet': 'Fabienne Marthe Pierrette Harun',
#    'nom_usage': 'Mialane',
#    'pays': 'FRANCE',
#    'pays_de_naissance': 'FRANCE',
#    'personne_morale': False,
#    'prenom': 'Fabienne, Marthe, Pierrette',
#    'prenom_usuel': 'Fabienne',
#    'qualite': 'Directeur général délégué',
#    'qualites': ['Directeur général délégué'],
#    'sexe': 'F',
#    'ville': 'Le Plessis-Trévise',
#    'ville_de_naissance': 'Montfermeil'}],
#  'rnm': None,
#  'sexe': None,
#  'siege': {'adresse_ligne_1': '33 RUE DU PONT NEUF',
#   'adresse_ligne_2': None,
#   'annee_effectif': 2022,
#   'code_naf': '56.10A',
#   'code_pays': 'FR',
#   'code_postal': '75001',
#   'complement_adresse': None,
#   'date_cessation': None,
#   'date_de_creation': '1980-07-01',
#   'diffusion_partielle': False,
#   'domiciliation': None,
#   'effectif': 'Entre 20 et 49 salariés',
#   'effectif_max': 49,
#   'effectif_min': 20,
#   'enseigne': ' LE CHIEN QUI FUME ',
#   'etablissement_cesse': False,
#   'etablissement_employeur': True,
#   'indice_repetition': None,
#   'latitude': 48.86131199980185,
#   'libelle_code_naf': 'Restauration traditionnelle',
#   'libelle_voie': 'DU PONT NEUF',
#   'longitude': 2.3448640000027132,
#   'nic': '00028',
#   'nom_commercial': 'LE CHIEN QUI FUME',
#   'numero_voie': 33,
#   'pays': 'France',
#   'predecesseurs': [{'continuite_economique': True,
#     'date': '2005-01-01',
#     'siret': '31013032300010',
#     'transfert_siege': True}],
#   'siege': True,
#   'siret': '31013032300028',
#   'siret_formate': '310 130 323 00028',
#   'tranche_effectif': '12',
#   'type_voie': 'RUE',
#   'ville': 'PARIS'},
#  'sigle': None,
#  'siren': '310130323',
#  'siren_formate': '310 130 323',
#  'societe_a_mission': None,
#  'statut_rcs': 'Inscrit',
#  'statut_rne': 'Inscrit',
#  'tranche_effectif': '12'}
