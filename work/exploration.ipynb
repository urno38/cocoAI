# %%
from pathlib import Path
import pandas as pd


COCOAI_PATH = Path('c:\\Users\\urnoc\\Documents\\cocoAI')

# %%
df = pd.read_csv(COCOAI_PATH/'data/pappers.csv',delimiter=';')

# %%
df
# Out:
#          siren siren_formate       nom_entreprise  personne_morale  \
# 0    391251030   391 251 030              ELIODOR                1
# 1    324294735   324 294 735          SAS ANDRIEU                1
# 2    325645661   325 645 661   MAISON PETRICORENA                1
# 3    750199390   750 199 390  CHARLY RESTAURATION                1
# 4    420911299   420 911 299             CAUDALIE                1
# ..         ...           ...                  ...              ...
# 395  424746436   424 746 436         SARL CARAULA                1
# 396  477733331   477 733 331         ZAMORA ALAIN                0
# 397  499708568   499 708 568       EXILARD JEROME                0
# 398  682711429   682 711 429       SOLORZANO JEAN                0
# 399  419150859   419 150 859      HIERE JEAN-PAUL                0
#
#             denomination        nom     prenom sexe  \
# 0                ELIODOR        NaN        NaN  NaN
# 1            SAS ANDRIEU        NaN        NaN  NaN
# ...
