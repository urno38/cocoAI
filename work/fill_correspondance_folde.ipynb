# %%
import pandas as pd
from common.path import COMMON_PATH
dfi = pd.read_csv(COMMON_PATH/'correspondance_folder.csv',index_col=0)

# %%
from common.AI_API import ask_Mistral
from common.keys import MISTRAL_API_KEY
import json

def get_siret(etname):
    
    chat_response = ask_Mistral(
        api_key=MISTRAL_API_KEY,
        prompt=f"trouve le siret de l'établissement BILLY BILLI",
        model="mistral-large-latest",
        json_only=True,
    )
    # LOGGER.debug(chat_response)
    json_dict = chat_response.choices[0].message.content
    print(json_dict)
    # LOGGER.debug(json_dict)
    response_dict2 = json.loads(json_dict)

    response_dict2["SIRET"] = int(
        response_dict2["SIRET"].replace(".", "").replace(" ", "")
    )
    
    
    # return siret



get_siret('BILLI BILLI')

# %%
di = {
  "GRAND CARNOT": "79895243800017",
  "DEI FRATELLI": "42507282400032",
  "GENTLEMEN": "53838231800029",
  "MANHATTAN TERRAZZA": "84895905200012",
  "RALLYE PASSY (BOUILLON PASSY)": "31181081600018",
  "AFFRANCHIS": "39097189300024",
  "ANDORINHA": "Non trouvé",
  "AQUABIKE": "81263402000018",
  "ASCENSION": "41866146800045",
  "ASIAN KITCHEN": "Non trouvé",
  "ASSOCIES": "Non trouvé",
  "AVELLINO": "Non trouvé",
  "AZZURO": "Non trouvé",
  "BAIGNEUSES": "Non trouvé",
  "BAR DES SPORT": "Non trouvé",
  "BARIOLÉ": "Non trouvé",
  "BEBER": "Non trouvé",
  "BILLY BILLI": "Non trouvé",
  "BISTROT BALNÉAIRE": "Non trouvé",
  "BISTROT CHARBON": "Non trouvé",
  "BISTROT DE RUNGIS": "Non trouvé",
  "BISTROT DU FAUBOURG": "Non trouvé",
  "BOIS LE VENT": "Non trouvé",
  "BON JACQUES": "Non trouvé",
  "BOUDOIR": "Non trouvé",
  "BOULANGERIE DE L'OLYMPIA": "Non trouvé",
  "BOULEDOGUE": "Non trouvé",
  "BRASSERIE LOLA": "Non trouvé",
  "BRIoche DORÉE": "Non trouvé",
  "BROOKLYN CAFE": "Non trouvé",
  "CAFE DU MEXIQUE": "Non trouvé",
  "CAFÉ DE L'ÉGLISE": "Non trouvé",
  "CANTINA": "Non trouvé",
  "CHEZ BEBER": "Non trouvé",
  "CHIEN QUI FUME": "Non trouvé",
  "CIAL": "Non trouvé",
  "CLAUDIA": "Non trouvé",
  "CLOS BOURGUIGNON": "Non trouvé",
  "COMPAGNIE": "Non trouvé",
  "DA ROSA": "Non trouvé",
  "DIPLOMATE": "Non trouvé",
  "DODDY'S": "Non trouvé",
  "EL SOL": "Non trouvé",
  "FAJITAS": "Non trouvé",
  "GERMAIN": "Non trouvé",
  "GRILLON": "Non trouvé",
  "GROUPE DORR": "Non trouvé",
  "HIPPOPOTAMUS BASTILLE": "Non trouvé",
  "IL PARADISIO": "Non trouvé",
  "JAD": "Non trouvé",
  "LE DIPLOMATE": "Non trouvé",
  "LOUIS XVI": "Non trouvé",
  "MADELEINE 7": "Non trouvé",
  "MAISON DE L'INFANTE": "Non trouvé",
  "MAISON MULOT": "Non trouvé",
  "MAMMA ROMA": "Non trouvé",
  "MAMY CREPES": "Non trouvé",
  "MARÉCHAL BRUNE": "Non trouvé",
  "MIZON": "Non trouvé",
  "MONSIEUR LE ZINC": "Non trouvé",
  "MOULIN DE LA GALETTE": "Non trouvé",
  "MUSÉE DU CHOCOLAT": "Non trouvé",
  "NOMAD'S": "Non trouvé",
  "NOVIMENTO": "Non trouvé",
  "O'NIEL": "Non trouvé",
  "PACHYDERME": "Non trouvé",
  "PAOLA": "Non trouvé",
  "PAPARAZZI": "Non trouvé",
  "PETIT BOUILLON VAVIN": "Non trouvé",
  "PETIT LUX": "Non trouvé",
  "PETITES CANAILLES": "Non trouvé",
  "PETITES MAISONS": "Non trouvé",
  "PIPPA": "Non trouvé",
  "PLACE": "Non trouvé",
  "PORTE MONTMARTRE": "Non trouvé",
  "PRÉVOYANT": "Non trouvé",
  "RICHER": "Non trouvé",
  "SOPI": "Non trouvé",
  "STARBUCKS CAFÉ": "Non trouvé",
  "STELLAS MARIS": "Non trouvé",
  "TAM": "Non trouvé",
  "TÉLÉPHONES": "Non trouvé",
  "TONTON BECTON": "Non trouvé",
  "TOUR MAUBOURG": "Non trouvé",
  "TRATTORIA CHIC": "Non trouvé",
  "TROUVILLE": "Non trouvé",
  "VALOIS": "Non trouvé",
  "VERSAILLES": "Non trouvé",
  "VILLA DU MUSÉE": "Non trouvé",
  "VILLA FLEURY": "Non trouvé",
  "WOOD": "Non trouvé",
  "ZACK RESTAURANT": "Non trouvé",
  "ZIGZAG": "Non trouvé",
  "HOTEL LOUIS II (H.BOUDAHOUT)": "Non trouvé",
  "HOTEL TOUR EIFFEL": "Non trouvé",
  "CHEZ CLAUDE": "Non trouvé",
  "CORDONNERIE": "Non trouvé",
  "ANNA": "Non trouvé",
  "IMMEUBLE APT + MURS  (H.BOUDAHOUT)": "Non trouvé",
  "IMMEUBLE CHAUSSÉE D'ANTIN": "Non trouvé",
  "IMMEUBLE VERSAILLES": "Non trouvé",
  "BOULANGERIE_HANNECART": "Non trouvé",
  "MURS BUREAUX 61 RENNES 75006": "Non trouvé",
  "CERTAS": "Non trouvé",
  "MONCEAU_FLEURS": "Non trouvé",
  "LESCOT": "Non trouvé",
  "ABRADAVIO": "Non trouvé",
  "ABSINTHE CAFE": "Non trouvé",
  "AMBASSADE D'AUVERGNE": "Non trouvé",
  "AVENIR": "Non trouvé",
  "BEAUX PARLEURS": "Non trouvé",
  "BISTROT VALOIS": "Non trouvé",
  "BOULANGERIE": "Non trouvé",
  "COMPTOIR LOZ": "Non trouvé",
  "PAVÉ": "Non trouvé",
  "PETIT VENDÔME": "Non trouvé",
  "RECAMIER": "Non trouvé"
}

# %%
ser = pd.Series(di)

# %%
df = dfi.set_index('ENSEIGNE')
df['SIRET'] = ser

# %%
df.to_csv('tutu.csv')

# %%
dfi.folder

# %%
from pathlib import Path
import pandas as pd
df2= pd.read_excel(Path(r'C:\Users\lvolat\Documents\cocoAI\common\bdd_SIRET.xlsx'))

# %%
from cocoAI.company import get_infos_from_a_siren

for e, s in df2.reset_index()[["ENSEIGNE", "SIRET"]].dropna().iterrows():
    # print(i)
    # print(ENSEIGNE,SIRET)
    print(s["ENSEIGNE"], s["SIRET"])
    if s["SIRET"] != "Non trouvé":
        get_infos_from_a_siren(str(s["SIRET"])[:-5])

# %%
for et in df2.folder.values:
    print(f"Trouve le SIRET de l'etablissement {et}")

# %%
print(df2.folder.values)

# %%
di = {
    "CASA DI MARIO - 75007 PARIS - 132 Rue du BAC": "53119288800018",
    "DEI FRATELLI - 75001 PARIS - 10 Rue des PYRAMIDES": "83995102700011",
    "GENTLEMEN - JARDINS DE L'ARCHE - 92000 NANTERRE": "80449572900035",
    "GRAND CARNOT (Le) - 75017 PARIS - 32 Avenue CARNOT angle 40 Rue des ACACIAS": "79895243800017",
    "MANHATTAN TERRAZZA - 108 Av de VILLIERS - 75017 PARIS": "88096301200014",
    "RALLYE PASSY (BOUILLON PASSY) - 75016 PARIS - 34 Rue de l'ANNONCIATION": "48747486800022",
    "AFFRANCHIS (Les) - 75012 PARIS - 14 Avenue DAUMESNIL": "84492436500027",
    "ANDORINHA - 75016 PARIS - 199 Avenue de VERSAILLES - ex VERSAILLES AVENUE - MONTCASTEL": "79903742900014",
    "AQUABIKE - 75015 PARIS - 45 Avenue de la MOTTE-PICQUET": "43776601700010",
    "ASCENSION - 75018 - 62 RUE CUSTINE": "79854416900016",
    "ASIAN KITCHEN - 75007 PARIS - 49 Quai d'ORSAY - 20240925": "42507282400011",
    "ASSOCIES (Les) - 75012 PARIS - 50 Bld de la BASTILLE": "43472611300013",
    "AVELLINO - 4 Bld Richard WALLACE - 92800 PUTEAUX": "53862111100013",
    "AZZURO - 92100 BOULOGNE-BILLANCOURT - 59 Place René CLAIR": "38027351600019",
    "BAIGNEUSES (Les) - 64200 BIARRITZ - 14 Rue du PORT VIEUX": "40101719900014",
}

# %%
from cocoAI.company import get_infos_from_a_siren
for v in di.values():
    get_infos_from_a_siren(str(v)[:-5])
